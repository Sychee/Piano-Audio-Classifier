# %%
from audioNet import *
from twilio.rest import Client

# %%
def twilioMessage(testnum=0, acc=0, time=0, message=None):
    # Your Account Sid and Auth Token from twilio.com / console 
    account_sid = ''
    auth_token = '' #PRIVATE

    if message:
        text = message
    else:
        text = f'TEST {testnum}, TEST ACC: {acc:.2f}%, TOTIME: {time:.2f} hours'
    
    client = Client(account_sid, auth_token) 
    message = client.messages.create( 
                    from_='+14804053343', to ='+14087723101',
                    body = text
                    )
    print(text)

# %%
TEST_NUM = 5
required_training = False

BATCH_SIZE = 16
EPOCHS_COUNT = 20
LEARNING_RATE = 0.1

class AudioNet(nn.Module):
    def __init__(self):
        super().__init__() 
        
        self._head = nn.Sequential(
        nn.Linear(in_features=92, out_features=300), # 1st layer
        nn.ReLU(inplace=True),

        nn.Linear(in_features=300, out_features=600), # 2nd layer
        nn.ReLU(inplace=True),
            
        nn.Linear(in_features=600, out_features=300), # 3rd layer
        nn.ReLU(inplace=True),
        
        nn.Linear(in_features=300, out_features=35531) # output layer
        )
        
    def forward(self, x):
        x = x.view(x.size()[0], -1)
        x = self._head(x)
        return x
    
if required_training:
    model, epoch_train_loss, epoch_train_acc, epoch_test_loss, epoch_test_acc, elapsed = \
    main(batch_size=BATCH_SIZE, epochs_count=EPOCHS_COUNT, learning_rate=LEARNING_RATE, neuralModel=AudioNet())
    twilioMessage(testnum=TEST_NUM, acc=epoch_test_acc[-1]*100, time=elapsed/60/60)

# %%
TEST_NUM = 6
required_training = True

BATCH_SIZE = 16
EPOCHS_COUNT = 20
LEARNING_RATE = 0.1

class AudioNet(nn.Module):
    def __init__(self):
        super().__init__() 
        
        self._head = nn.Sequential(
        nn.Linear(in_features=92, out_features=300), # 1st layer
        nn.ReLU(inplace=True),

        nn.Linear(in_features=300, out_features=1000), # 2nd layer
        nn.ReLU(inplace=True),
            
        nn.Linear(in_features=1000, out_features=300), # 3rd layer
        nn.ReLU(inplace=True),
        
        nn.Linear(in_features=300, out_features=35531) # output layer
        )
        
    def forward(self, x):
        x = x.view(x.size()[0], -1)
        x = self._head(x)
        return x
    
if required_training:
    model, epoch_train_loss, epoch_train_acc, epoch_test_loss, epoch_test_acc, elapsed = \
    main(batch_size=BATCH_SIZE, epochs_count=EPOCHS_COUNT, learning_rate=LEARNING_RATE, neuralModel=AudioNet())
    twilioMessage(testnum=TEST_NUM, acc=epoch_test_acc[-1]*100, time=elapsed/60/60)
# Out:
# CUDA AVAILABLE
# USING 25% OF THE DATA
# Train Epoch: 0 [16000/226607] Loss: 8.060892 Acc: 0.0625
# Train Epoch: 0 [32000/226607] Loss: 9.765223 Acc: 0.0000
# Train Epoch: 0 [48000/226607] Loss: 9.315256 Acc: 0.0000
# Train Epoch: 0 [64000/226607] Loss: 7.784576 Acc: 0.0000
# Train Epoch: 0 [80000/226607] Loss: 9.201786 Acc: 0.0000
# Train Epoch: 0 [96000/226607] Loss: 6.490334 Acc: 0.1875
# Train Epoch: 0 [112000/226607] Loss: 7.903908 Acc: 0.0000
# Train Epoch: 0 [128000/226607] Loss: 7.313653 Acc: 0.0625
# Train Epoch: 0 [144000/226607] Loss: 6.532838 Acc: 0.0625
# Train Epoch: 0 [160000/226607] Loss: 6.798792 Acc: 0.1250
# Train Epoch: 0 [176000/226607] Loss: 5.899342 Acc: 0.1250
# Train Epoch: 0 [192000/226607] Loss: 6.747872 Acc: 0.1875
# Train Epoch: 0 [208000/226607] Loss: 7.435965 Acc: 0.1250
# Train Epoch: 0 [224000/226607] Loss: 5.552657 Acc: 0.1875
# Elapsed 118.09s, 118.09 s/epoch, 0.01 s/batch, ets 2243.73s
#
# Test set: Average loss: 5.7533, Accuracy: 14801/73447 (20%)
#
# Loss decreases, saving the model.
#
# Train Epoch: 1 [16000/226607] Loss: 5.699824 Acc: 0.1875
# Train Epoch: 1 [32000/226607] Loss: 5.511951 Acc: 0.1250
# Train Epoch: 1 [48000/226607] Loss: 5.714857 Acc: 0.2500

# %%
TEST_NUM = 7
required_training = True

BATCH_SIZE = 16
EPOCHS_COUNT = 20
LEARNING_RATE = 0.1

class AudioNet(nn.Module):
    def __init__(self):
        super().__init__() 
        
        # convolution layers
        self._body = nn.Sequential(

            nn.Conv2d(in_channels=1, out_channels=6, kernel_size=5),
            nn.BatchNorm2d(6),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2),
            
            # Second convolution layer
            nn.Conv2d(in_channels=6, out_channels=16, kernel_size=5),
            nn.BatchNorm2d(16),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2),
        )

        self._head = nn.Sequential(
        nn.Linear(in_features=92, out_features=300), # 1st layer
        nn.ReLU(inplace=True),

        nn.Linear(in_features=300, out_features=1000), # 2nd layer
        nn.ReLU(inplace=True),
            
        nn.Linear(in_features=1000, out_features=300), # 3rd layer
        nn.ReLU(inplace=True),
        
        nn.Linear(in_features=300, out_features=35531) # output layer
        )
        
    def forward(self, x):
        x = self._body(x)
        x = x.view(x.size()[0], -1)
        x = self._head(x)
        return x
    
if required_training:
    try:
        model, epoch_train_loss, epoch_train_acc, epoch_test_loss, epoch_test_acc, elapsed = \
        main(batch_size=BATCH_SIZE, epochs_count=EPOCHS_COUNT, learning_rate=LEARNING_RATE, neuralModel=AudioNet())
        twilioMessage(testnum=TEST_NUM, acc=epoch_test_acc[-1]*100, time=elapsed/60/60)
    except Exception as e:
        twilioMessage(message=f"ERROR ON TEST {TEST_NUM}: {e}")

# %%
twilioMessage(message="DONE, PLEASE GIVE ME MORE TESTS TO RUN")
